# %%
list1 = []
print(list1)
print(type(list1))
# Out:
# []
# <class 'list'>

# %%
list1 = ['India', "america"]
print(list1)
# Out:
# ['India', 'america']

# %%
country = list(list1)
print(country)
# Out:
# ['India', 'america']

# %%
list1 = list('Coding')
print(list1)
# Out:
# ['C', 'o', 'd', 'i', 'n', 'g']

# %%
list1 = list('Coding')
print(list1)
# Out:
# ['C', 'o', 'd', 'i', 'n', 'g']

# %%
list1 = list(['Coding'])
print(list1)
# Out:
# ['Coding']

# %%
list1 = list(('Coding',))
print(type(list1))
print(list1)
# Out:
# <class 'list'>
# ['Coding']

# %%
list1 = ('Coding',)
print(type(list1))
# Out:
# <class 'tuple'>

# %%
nested_list = [[1, 2, 3], [4, 5, 6], [7, 8, 9]]
print(nested_list)
# Out:
# [[1, 2, 3], [4, 5, 6], [7, 8, 9]]

# %%
income = [10000, 8000, 3000, 15000, 7500]
# Write your code here
avg_income = sum(income)/len(income)
print(avg_income)
# Out:
# 8700.0

# %%
username = input("enter your username")
if username == 'admin':
    password = input("enter your password")
    if password == '1234':
        print("Access granted")
        print(type(username))
        print(type(password))
    else:
        print("wrong password")
else:
    print("not found")
# Out:
# enter your username admin
# enter your password 1234
# Access granted
# <class 'str'>
# <class 'str'>

# %%
username = input()
print(type(username))
# Out:
# enter your username 1234
# <class 'str'>

# %%
a = list(map(int,input().split()))
b = list(map(int,input().split()))
if len(a) == 3 and len(b) == 3:
    dot = a[0]*b[0] + a[1]*b[1] + a[2]*b[2] 
    print("Dot Product is: ",dot)
else:
    print("Please enter exactly 3 values for each vector!")
# Out:
#  2 3 4
#  4 5 1
# Dot Product is:  27

# %%
str1 = 'Coding Ninjas'
print(str1[-5:-11])

# %%
print(str1.upper())
print(str1.lower())
print(str1.title())
print(str1.capitalize())
# Out:
# CODING NINJAS
# coding ninjas
# Coding Ninjas
# Coding ninjas

# %%
str1= 'coding'
str2= 'nonjas'
print(str1 + ' ' + str2)
# Out:
# coding nonjas

# %%
name = 'mohit'
age = 25
print(f" i m {name} , {age} years old")
print(" i m {} , {} years old".format(name,age))
print(" i m " + name + ", " + str(age) + " years old")
# Out:
#  i m mohit , 25 years old
#  i m mohit , 25 years old
#  i m mohit, 25 years old

# %%
print(name * 3)
# Out:
# mohitmohitmohit

# %%
str1 = 'pyhton is programming'
print(str1.replace('o','O'))
print(str1.replace('is','IS'))
# Out:
# pyhtOn is prOgramming
# pyhton IS programming

# %%
print(str1.split())
# Out:
# ['pyhton', 'is', 'programming']

# %%
str1 = '    coding    ninjas     '
print(str1.strip())
# Out:
# coding    ninjas

# %%
str1 = '$$$coding ninjas###'
print(str1.strip('$#'))
# Out:
# coding ninjas

# %%
str1 = 'this is a python'
print(str1.index('is',3))
print(str1.find('Is',3))
# Out:
# 5
# -1

# %%
print('coding'.isalpha())
print('coding12'.isalnum())
print('12'.isnumeric())
print('HI'.isupper())
print('hi'.islower())
print('CoDing'.swapcase())
# Out:
# True
# True
# True
# True
# True
# cOdING

# %%
str1 = 'hey, welcome to the world!'
# print(str1.startswith('he'))
# print(str1.startswith('wel',5))
# print(str1.endswith('!'))
# print(str1.endswith('ld!'))
# Out:
# True
# True
# True
# True

# %%
str1 = 'hey, welcome to the world!'
print(str1.count('hey'))
# Out:
# 1

# %%
string = 'this is a python iniii world'
print(string.count('is'))
print(str1.count('to'))
# Out:
# 2
# 1

# %%
print(string.count('i'))
# Out:
# 6

# %%
str2 = 'pyhton is good'
print(str2.count('is'))
# Out:
# 1

# %%
l1 = [1,2,3,4]
print(l1)
l1 = list((1,2,3,4,))
print(l1)
# Out:
# [1, 2, 3, 4]
# [1, 2, 3, 4]

# %%
l1 = list(('string',))
print(l1)
# Out:
# ['string']

# %%
l1 = list(['string'])
print(l1)
# Out:
# ['string']

# %%
nested = [1,2, [3,4,5], 'coding' ,True]
print(nested)
# Out:
# [1, 2, [3, 4, 5], 'coding', True]

# %%
print(len(nested))
# Out:
# 5

# %%
list1 = [10,20,30,40,True]
print(min(list1))
print(max(list1))
print(sum(list1))
# Out:
# True
# 40
# 101

# %%
list1 = ['asia', 'america', 'vanu', 'zah']
print(min(list1))
print(max(list1))
# Out:
# america
# zah

# %%
list1 = [11,22,33,44]
list1[1] = 80
print(list1)
# Out:
# [11, 80, 33, 44]

# %%
list1[1:3] = [20,30,40]
print(list1)
# Out:
# [11, 20, 30, 40, 40, 44]

# %%
list1.append(23)
print(list1)
# Out:
# [11, 24, 24, 24, 20, 30, 40, 40, 44, 23, 23]

# %%
list1.insert(1,24)
print(list1)
# Out:
# [11, 24, 24, 24, 20, 30, 40, 40, 44, 23]

# %%
list2 = [23,56]
list1.extend(list2)
print(list1)
# Out:
# [11, 24, 24, 24, 20, 30, 40, 40, 44, 23, 23, 23, 56, 23, 56]
