# %%
n = input()
x = float(n)
print(x**2)
# Out:
#  4
# 16.0

# %%
n1 = input()
n2 = input()

x1 = int(n1)
x2 = int(n2)

print(x1+x2)
print(x1-x2)
print(x1*x2)
print(x1//x2)
# Out:
#  7
#  3
# 10
# 4
# 21
# 2

# %%
n = list(map(int,input().split()))
n.sort(reverse = True)
print(n[1])
# Out:
#  3 1 4 2
# 3

# %%
n = list(map(int,input().split()))
y = set(n)
print(len(y))
# Out:
#  1 2 3 1 2 3 4 5 5
# 5

# %%
n = input()
mid = len(n) // 2
print(n[:mid][::-1] + n[mid:])
# Out:
#  hello
# ehllo

# %%
n = input()

print('First character:',n[0])
print('Last character:',n[-1])
print('Middle substring:',n[1:-1])
print('Every second character:',n[::2])
# Out:
#  example
# First character: e
# Last character: e
# Middle substring: xampl
# Every second character: eape

# %%
n = input()

print(n[1::3])
# Out:
#  python
# yo

# %%
n = list(map(int,input().split()))

print(n[-3:][::-1])
# Out:
#  1 2 3 4 5 6 7
# [7, 6, 5]

# %%
lst = list(map(int, input().split()))
print(*lst[-3:][::-1])
# Out:
#  1 2 3 4 5 6 7
# 7 6 5

# %%
s = input()
print('[' + '-'.join(s) + ']')
# Out:
#  pyhton
# [p-y-h-t-o-n]

# %%
s = input()
print("[" + "-".join(list(s)) + "]")
# Out:
#  python
# [p-y-t-h-o-n]

# %%
s = 'pyhton'
print('-'.join(s))
# Out:
# p-y-h-t-o-n

# %%
n = list(map(int,input().split()))

squared = list(map(lambda x : x*2 , n))
print(*squared)
# Out:
#  1 2  3 4  5
# 2 4 6 8 10

# %%
email = input()
sub = input()

print(email.startswith(sub))
# Out:
#  user@gmail.com
#  user
# True

# %%
a,b = list(map(int,input().split()))

print(abs(a-b))
# Out:
#  10 6
# 4

# %%
n = input()

print(int(n,3))
# Out:
#  1111
# 40

# %%
x = set(map(int,input().split()))
y = set(map(int,input().split()))

result = x.union(y)
print(result)
# Out:
#  1 2 3
#  3 4 5
# {1, 2, 3, 4, 5}

# %%
num = input().split()
num = num[:4]
_dict = {}

for n in num:
    _dict[n] = str(int(n)**2)

print(_dict)
# Out:
#  0 -1 2 -3 4
# {'0': '0', '-1': '1', '2': '4', '-3': '9'}

# %%
n = input().split()

keys = n[::2]
values = n[1::2]

values = list(map(int,values))

zip_dict = dict(zip(keys,values))
print(zip_dict)
# Out:
#  a 1 b 2 c 3
# {'a': 1, 'b': 2, 'c': 3}

# %%
n = input()

x = n.replace(" ","").lower()

print(x == x[::-1])
# Out:
#  Light
# False

# %%
x = int(input())

result = 3*x**4 + 2*x**3 - x**2 + 4*x - 5

print(result)
# Out:
#  2
# 63
