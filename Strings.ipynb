# %%
a = 2
b = 2
c =2
print(id(a))
print(id(b))
print(id(c))
# Out:
# 140725546038216
# 140725546038216
# 140725546038216

# %%
# Indexing
string = 'Coding Ninjas'
print(string[0])
print(string[-1])
# Out:
# C
# s

# %%
print(string[-14])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 print(string[-14])
#
# IndexError: string index out of range

# %%
string = 'Coding Ninjas'
print(string[:6])
print(string[7:])
print(string[1:6])
print(string[13:15])
print(string[0:12:2])
print(string[-11:7:1])
print(string[-5:-11:-2])
# Out:
# Coding
# Ninjas
# oding
#
# Cdn ij
# ding
# i n

# %%
print(string[-4:])
print(string[:-5])
print(string[-3:0:-1])
# Out:
# njas
# Coding N
# jniN gnido

# %%
print(string[:])
print(string[::-1])
print(string[::1])
# Out:
# Coding Ninjas
# sajniN gnidoC
# Coding Ninjas

# %%
print(string[-5:-11:-2])
# Out:
# i n

# %%
string = 'Python is Awesome'
print(len(string))
print(string.lower())
print(string.upper())
print(string.title())
print(string.capitalize())
# Out:
# 17
# python is awesome
# PYTHON IS AWESOME
# Python Is Awesome
# Python is awesome

# %%
print(string.split(' '))
# Out:
# ['Python', 'is', 'Awesome']

# %%
print(string * 3)
# Out:
# Python is AwesomePython is AwesomePython is Awesome

# %%
print(string.replace('o','O'))
# Out:
# PythOn is AwesOme

# %%
print('###pyhton##'.strip('#'))
# Out:
# pyhton

# %%
str1 = 'This is a pyhton'
print(str1.index('is'))
print(str1.index('is',3,10))
# Out:
# 2
# 5

# %%
path = str(input())
p1 = path.split('/')
print("File Name: " + p1[-1])

p2 = p1[-1]

p3 = p2.split('.')
print("File Extension: " + p3[-1])
print("Reversed Base Name: " + p3[0][::-1] )
# Out:
#  C:/Users/JohnDoe/Documents/Report.txt
# File Name: Report.txt
# File Extension: txt
# Reversed Base Name: tropeR

# %%
path = "C:/Users/JohnDoe/Documents/Report.txt"

# Extract file name (after last '/')
print(path.find('/'))
file_name = path[path.find('/') + 1:]
print(file_name)
# Out:
# 2
# Users/JohnDoe/Documents/Report.txt

# %%
num = '123456789012'
masked_number = '*'* 8 + num[-4:]
print(masked_number)
# Out:
# ********9012
