# %%
import pandas as pd
Customers = pd.read_excel('customers.xlsx')
Products = pd.read_excel('products.xlsx')
Purchases = pd.read_excel('purchases.xlsx')

# %%
Customers.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 11 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             1000 non-null   int64
#  1   first_name     1000 non-null   object
#  2   last_name      1000 non-null   object
#  3   email          878 non-null    object
#  4   gender         957 non-null    object
#  5   street_num     738 non-null    float64
#  6   street_name    963 non-null    object
#  7   street_suffix  963 non-null    object
#  8   city           921 non-null    object
#  9   state          920 non-null    object
#  10  postcode       843 non-null    float64
# dtypes: float64(2), int64(1), object(8)
# memory usage: 86.1+ KB

# %%
Customers.columns
# Out:
# Index(['id', 'first_name', 'last_name', 'email', 'gender', 'street_num',
#        'street_name', 'street_suffix', 'city', 'state', 'postcode'],
#       dtype='object')

# %%
Customers['gender'].value_counts()
# Out:
# gender
# Male      485
# Female    472
# Name: count, dtype: int64

# %%
Customers.head()
# Out:
#    id first_name   last_name                      email  gender  street_num  \
# 0   1     Romain   Southcott  rsouthcott0@clickbank.net    Male         1.0
# 1   2     Cosimo   Molyneaux      cmolyneaux1@wiley.com    Male         NaN
# 2   3      Bambi     Westrip     bwestrip2@symantec.com  Female      4057.0
# 3   4     Roarke  Pankettman     rpankettman3@wiley.com    Male        74.0
# 4   5    Mikaela    Althorpe           malthorpe4@51.la     NaN         NaN
#
#   street_name street_suffix         city       state  postcode
# 0   Trailsway          Road    San Diego  California   92127.0
# 1         NaN           NaN      El Paso       Texas       NaN
# 2    Arkansas        Circle  San Antonio       Texas   78220.0
# 3        Debs         Point      Memphis   Tennessee   38150.0
# 4         2nd         Drive          NaN         NaN   83732.0

# %%
Customers.iloc[0]
# Out:
# id                                       1
# first_name                          Romain
# last_name                        Southcott
# email            rsouthcott0@clickbank.net
# gender                                Male
# street_num                             1.0
# street_name                      Trailsway
# street_suffix                         Road
# city                             San Diego
# state                           California
# postcode                           92127.0
# Name: 0, dtype: object

# %%
Customers.iloc[1:3, 1:3]
# Out:
#   first_name  last_name
# 1     Cosimo  Molyneaux
# 2      Bambi    Westrip

# %%
Customers.loc[1:3, ['gender', 'city']]
# Out:
#    gender         city
# 1    Male      El Paso
# 2  Female  San Antonio
# 3    Male      Memphis

# %%
Customers.loc[1]
# Out:
# id                                   2
# first_name                      Cosimo
# last_name                    Molyneaux
# email            cmolyneaux1@wiley.com
# gender                            Male
# street_num                         NaN
# street_name                        NaN
# street_suffix                      NaN
# city                           El Paso
# state                            Texas
# postcode                           NaN
# Name: 1, dtype: object

# %%
Customers[Customers['id'] == 1000]
# Out:
#        id first_name last_name email gender  street_num street_name  \
# 999  1000     Elmore    Malpas   NaN   Male       205.0     Farwell
#
#     street_suffix     city    state  postcode
# 999          Park  Atlanta  Georgia   30386.0

# %%
Customers[Customers['state'] == 'Texas']
# Out:
#       id first_name    last_name                     email  gender  \
# 1      2     Cosimo    Molyneaux     cmolyneaux1@wiley.com    Male
# 2      3      Bambi      Westrip    bwestrip2@symantec.com  Female
# 17    18   Reinhold    Woolforde        rwoolfordeh@cbc.ca    Male
# 19    20     Rubina     Hustings  rhustingsj@wikimedia.org  Female
# 20    21      Karim      Woosnam       kwoosnamk@ifeng.com    Male
# ..   ...        ...          ...                       ...     ...
# 956  957     Ruddie      Eckhard        reckhardqk@free.fr    Male
# 969  970  Georgetta    Bartoszek        gbartoszekqx@is.gd  Female
# 973  974     Ingmar  Muzzlewhite                       NaN    Male
# 976  977     Corena         Pelz                       NaN  Female
# 981  982     Judith        Otham                       NaN  Female
#
#      street_num   street_name street_suffix         city  state  postcode
# 1           NaN           NaN           NaN      El Paso  Texas       NaN
# ...

# %%
Customers.index
# Out:
# RangeIndex(start=0, stop=1000, step=1)

# %%
Customers.columns
# Out:
# Index(['id', 'first_name', 'last_name', 'email', 'gender', 'street_num',
#        'street_name', 'street_suffix', 'city', 'state', 'postcode'],
#       dtype='object')

# %%
 print(Customers['city'].dtypes)
# Out:
# object

# %%
Customers.describe(include = 'all')
# Out:
#                  id first_name last_name                           email  \
# count   1000.000000       1000      1000                             878
# unique          NaN        932       993                             878
# top             NaN      Berty  Sedworth  istandbrookerq@yellowpages.com
# freq            NaN          4         3                               1
# mean     500.500000        NaN       NaN                             NaN
# std      288.819436        NaN       NaN                             NaN
# min        1.000000        NaN       NaN                             NaN
# 25%      250.750000        NaN       NaN                             NaN
# 50%      500.500000        NaN       NaN                             NaN
# 75%      750.250000        NaN       NaN                             NaN
# max     1000.000000        NaN       NaN                             NaN
#
#        gender    street_num    street_name street_suffix        city  state  \
# ...

# %%
Customers.size
# Out:
# 11000

# %%
Customers.values
# Out:
# array([[1, 'Romain', 'Southcott', ..., 'San Diego', 'California',
#         92127.0],
#        [2, 'Cosimo', 'Molyneaux', ..., 'El Paso', 'Texas', nan],
#        [3, 'Bambi', 'Westrip', ..., 'San Antonio', 'Texas', 78220.0],
#        ...,
#        [998, 'Tobit', 'Birt', ..., 'Waterbury', 'Connecticut', 6721.0],
#        [999, 'Issiah', 'Standbrooke', ..., 'Savannah', 'Georgia',
#         31405.0],
#        [1000, 'Elmore', 'Malpas', ..., 'Atlanta', 'Georgia', 30386.0]],
#       dtype=object)

# %%
Customers.ndim
# Out:
# 2

# %%
Customers.shape[1]
# Out:
# 11

# %%
Products[Products['product'].str.contains('Nut')]
# Out:
#     Unnamed: 0  id                        product    cost company
# 2            2   3             Bar Bran Honey Nut  $65.40    Ntag
# 57          57  58             Bar Bran Honey Nut  $73.05  Yakijo
# 58          58  59  Nut - Almond, Blanched, Whole  $74.28   Eazzy

# %%
Customers['country'] = 'USA'

# %%
Customers
# Out:
#        id first_name    last_name                           email  gender  \
# 0       1     Romain    Southcott       rsouthcott0@clickbank.net    Male
# 1       2     Cosimo    Molyneaux           cmolyneaux1@wiley.com    Male
# 2       3      Bambi      Westrip          bwestrip2@symantec.com  Female
# 3       4     Roarke   Pankettman          rpankettman3@wiley.com    Male
# 4       5    Mikaela     Althorpe                malthorpe4@51.la     NaN
# ..    ...        ...          ...                             ...     ...
# 995   996    Merrili        Alman            malmanrn@cornell.edu  Female
# 996   997    Winonah       Heckle               whecklero@fc2.com  Female
# 997   998      Tobit         Birt                             NaN    Male
# 998   999     Issiah  Standbrooke  istandbrookerq@yellowpages.com    Male
# 999  1000     Elmore       Malpas                             NaN    Male
#
#      street_num street_name street_suffix          city         state  \
# ...

# %%
 Customers['full_name'] = Customers['first_name'] +' '+ Customers['last_name']

# %%
Customers.head()
# Out:
#    id first_name   last_name                      email  gender  street_num  \
# 0   1     Romain   Southcott  rsouthcott0@clickbank.net    Male         1.0
# 1   2     Cosimo   Molyneaux      cmolyneaux1@wiley.com    Male         NaN
# 2   3      Bambi     Westrip     bwestrip2@symantec.com  Female      4057.0
# 3   4     Roarke  Pankettman     rpankettman3@wiley.com    Male        74.0
# 4   5    Mikaela    Althorpe           malthorpe4@51.la     NaN         NaN
#
#   street_name street_suffix         city       state  postcode country  \
# 0   Trailsway          Road    San Diego  California   92127.0     USA
# 1         NaN           NaN      El Paso       Texas       NaN     USA
# 2    Arkansas        Circle  San Antonio       Texas   78220.0     USA
# 3        Debs         Point      Memphis   Tennessee   38150.0     USA
# 4         2nd         Drive          NaN         NaN   83732.0     USA
#
#            full_name
# 0   Romain Southcott
# 1   Cosimo Molyneaux
# ...

# %%
Customers.drop(columns = 'full_name' , inplace = True)

# %%
Customers
# Out:
#        id first_name    last_name                           email  gender  \
# 0       1     Romain    Southcott       rsouthcott0@clickbank.net    Male
# 1       2     Cosimo    Molyneaux           cmolyneaux1@wiley.com    Male
# 2       3      Bambi      Westrip          bwestrip2@symantec.com  Female
# 3       4     Roarke   Pankettman          rpankettman3@wiley.com    Male
# 4       5    Mikaela     Althorpe                malthorpe4@51.la     NaN
# ..    ...        ...          ...                             ...     ...
# 995   996    Merrili        Alman            malmanrn@cornell.edu  Female
# 996   997    Winonah       Heckle               whecklero@fc2.com  Female
# 997   998      Tobit         Birt                             NaN    Male
# 998   999     Issiah  Standbrooke  istandbrookerq@yellowpages.com    Male
# 999  1000     Elmore       Malpas                             NaN    Male
#
#      street_num street_name street_suffix          city         state  \
# ...

# %%
Customers.drop(index = [997,998] , axis = 0 , inplace = True)

# %%
Customers
# Out:
#       id first_name   last_name                      email  gender  \
# 0      1     Romain   Southcott  rsouthcott0@clickbank.net    Male
# 1      2     Cosimo   Molyneaux      cmolyneaux1@wiley.com    Male
# 2      3      Bambi     Westrip     bwestrip2@symantec.com  Female
# 3      4     Roarke  Pankettman     rpankettman3@wiley.com    Male
# 4      5    Mikaela    Althorpe           malthorpe4@51.la     NaN
# ..   ...        ...         ...                        ...     ...
# 992  993    Johnath      Clancy      jclancyrk@smugmug.com  Female
# 993  994     Binnie      Dearth           bdearthrl@ed.gov     NaN
# 994  995      Brana       Dixon       bdixonrm@myspace.com  Female
# 995  996    Merrili       Alman       malmanrn@cornell.edu  Female
# 996  997    Winonah      Heckle          whecklero@fc2.com  Female
#
#      street_num street_name street_suffix          city         state  \
# 0           1.0   Trailsway          Road     San Diego    California
# ...

# %%
Customers.rename(columns = {'street_num' : 'street_number'}, inplace = True)
Customers
# Out:
#       id first_name   last_name                      email  gender  \
# 0      1     Romain   Southcott  rsouthcott0@clickbank.net    Male
# 1      2     Cosimo   Molyneaux      cmolyneaux1@wiley.com    Male
# 2      3      Bambi     Westrip     bwestrip2@symantec.com  Female
# 3      4     Roarke  Pankettman     rpankettman3@wiley.com    Male
# 4      5    Mikaela    Althorpe           malthorpe4@51.la     NaN
# ..   ...        ...         ...                        ...     ...
# 992  993    Johnath      Clancy      jclancyrk@smugmug.com  Female
# 993  994     Binnie      Dearth           bdearthrl@ed.gov     NaN
# 994  995      Brana       Dixon       bdixonrm@myspace.com  Female
# 995  996    Merrili       Alman       malmanrn@cornell.edu  Female
# 996  997    Winonah      Heckle          whecklero@fc2.com  Female
#
#      street_number street_name street_suffix          city         state  \
# 0              1.0   Trailsway          Road     San Diego    California
# ...

# %%
Customers['gender'].unique()
# Out:
# array(['Male', 'Female', nan], dtype=object)

# %%
Customers['gender'].nunique()
# Out:
# 2

# %%
Customers.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 997 entries, 0 to 996
# Data columns (total 12 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             997 non-null    int64
#  1   first_name     997 non-null    object
#  2   last_name      997 non-null    object
#  3   email          877 non-null    object
#  4   gender         954 non-null    object
#  5   street_number  736 non-null    float64
#  6   street_name    960 non-null    object
#  7   street_suffix  960 non-null    object
#  8   city           918 non-null    object
#  9   state          917 non-null    object
#  10  postcode       997 non-null    int64
#  11  country        997 non-null    object
# dtypes: float64(1), int64(2), object(9)
# memory usage: 93.6+ KB

# %%
Customers['postcode'] = Customers['postcode'].fillna(0).astype(int)

# %%
Purchases
# Out:
#       Unnamed: 0    id           purch_date  customer_num  product_num  \
# 0              0     1  2019-01-03 00:00:00           823           27
# 1              1     2  2019-01-03 00:00:00           606           28
# 2              2     3  2019-01-03 00:00:00           955            9
# 3              3     4  2019-01-03 00:00:00           577           19
# 4              4     5  2019-01-03 00:00:00           429            8
# ...          ...   ...                  ...           ...          ...
# 5995        5995  5996           06/20/2019           893           33
# 5996        5996  5997           06/20/2019           566           23
# 5997        5997  5998           06/20/2019           114           19
# 5998        5998  5999           06/20/2019           404           11
# 5999        5999  6000           06/20/2019            88           57
#
#       amount    paid
# 0         12  568.92
# 1         14  395.36
# 2         17  510.17
# 3          3   68.49
# ...

# %%
Purchases['paid'] = Purchases['paid'].astype('str').str.replace('$','', regex = True).astype(float)

# %%
Purchases['purch_date'] = pd.to_datetime(Purchases['purch_date'])

# %%
Purchases.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6000 entries, 0 to 5999
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Unnamed: 0    6000 non-null   int64
#  1   id            6000 non-null   int64
#  2   purch_date    6000 non-null   datetime64[ns]
#  3   customer_num  6000 non-null   int64
#  4   product_num   6000 non-null   int64
#  5   amount        6000 non-null   int64
#  6   paid          6000 non-null   float64
# dtypes: datetime64[ns](1), float64(1), int64(5)
# memory usage: 328.3 KB

# %%
merged = pd.merge(Customers, Purchases, on = 'id' , how = 'right')
merged
# Out:
#         id first_name   last_name                      email  gender  \
# 0        1     Romain   Southcott  rsouthcott0@clickbank.net    Male
# 1        2     Cosimo   Molyneaux      cmolyneaux1@wiley.com    Male
# 2        3      Bambi     Westrip     bwestrip2@symantec.com  Female
# 3        4     Roarke  Pankettman     rpankettman3@wiley.com    Male
# 4        5    Mikaela    Althorpe           malthorpe4@51.la     NaN
# ...    ...        ...         ...                        ...     ...
# 5995  5996        NaN         NaN                        NaN     NaN
# 5996  5997        NaN         NaN                        NaN     NaN
# 5997  5998        NaN         NaN                        NaN     NaN
# 5998  5999        NaN         NaN                        NaN     NaN
# 5999  6000        NaN         NaN                        NaN     NaN
#
#       street_number street_name street_suffix         city       state  \
# ...

# %%
concat_df = pd.concat([Customers, Purchases], axis = 0)
concat_df
# Out:
#         id first_name   last_name                      email  gender  \
# 0        1     Romain   Southcott  rsouthcott0@clickbank.net    Male
# 1        2     Cosimo   Molyneaux      cmolyneaux1@wiley.com    Male
# 2        3      Bambi     Westrip     bwestrip2@symantec.com  Female
# 3        4     Roarke  Pankettman     rpankettman3@wiley.com    Male
# 4        5    Mikaela    Althorpe           malthorpe4@51.la     NaN
# ...    ...        ...         ...                        ...     ...
# 5995  5996        NaN         NaN                        NaN     NaN
# 5996  5997        NaN         NaN                        NaN     NaN
# 5997  5998        NaN         NaN                        NaN     NaN
# 5998  5999        NaN         NaN                        NaN     NaN
# 5999  6000        NaN         NaN                        NaN     NaN
#
#       street_number street_name street_suffix         city       state  \
# ...

# %%
joining = Customers.set_index('id').join(Purchases.set_index('id'))
joining
# Out:
#     first_name   last_name                      email  gender  street_number  \
# id
# 1       Romain   Southcott  rsouthcott0@clickbank.net    Male            1.0
# 2       Cosimo   Molyneaux      cmolyneaux1@wiley.com    Male            NaN
# 3        Bambi     Westrip     bwestrip2@symantec.com  Female         4057.0
# 4       Roarke  Pankettman     rpankettman3@wiley.com    Male           74.0
# 5      Mikaela    Althorpe           malthorpe4@51.la     NaN            NaN
# ..         ...         ...                        ...     ...            ...
# 993    Johnath      Clancy      jclancyrk@smugmug.com  Female            7.0
# 994     Binnie      Dearth           bdearthrl@ed.gov     NaN         8993.0
# 995      Brana       Dixon       bdixonrm@myspace.com  Female           97.0
# 996    Merrili       Alman       malmanrn@cornell.edu  Female            0.0
# 997    Winonah      Heckle          whecklero@fc2.com  Female          701.0
#
# ...

# %%
df1 = pd.DataFrame({'name':['A','B','C']}, index=[1,2,3])
df2 = pd.DataFrame({'salary':[500,600]}, index=[1,2])

print(df1)
df1.join(df2)
# Out:
#   name
# 1    A
# 2    B
# 3    C
#   name  salary
# 1    A   500.0
# 2    B   600.0
# 3    C     NaN

# %%
df1 = pd.DataFrame({
    'id':[1,2,3],
    'name':['A','B','C']
})

df2 = pd.DataFrame({
    'id':[1,2,4],
    'salary':[500,600,700]
})
print(df1)
pd.merge(df1, df2, on='id', how='inner')
# Out:
#    id name
# 0   1    A
# 1   2    B
# 2   3    C
#    id name  salary
# 0   1    A     500
# 1   2    B     600

# %%
import pandas as pd

df1 = pd.DataFrame({'A':[1,2], 'B':[3,4]})
df2 = pd.DataFrame({'A':[5,6], 'B':[7,8]})

pd.concat([df1, df2])
# Out:
#    A  B
# 0  1  3
# 1  2  4
# 0  5  7
# 1  6  8

# %%
Customers.isnull().sum().sum()
# Out:
# np.int64(657)

# %%
Customers.isnull().any().any()
# Out:
# np.True_

# %%
Customers
# Out:
#       id first_name   last_name                      email  gender  \
# 0      1     Romain   Southcott  rsouthcott0@clickbank.net    Male
# 1      2     Cosimo   Molyneaux      cmolyneaux1@wiley.com    Male
# 2      3      Bambi     Westrip     bwestrip2@symantec.com  Female
# 3      4     Roarke  Pankettman     rpankettman3@wiley.com    Male
# 4      5    Mikaela    Althorpe           malthorpe4@51.la     NaN
# ..   ...        ...         ...                        ...     ...
# 992  993    Johnath      Clancy      jclancyrk@smugmug.com  Female
# 993  994     Binnie      Dearth           bdearthrl@ed.gov     NaN
# 994  995      Brana       Dixon       bdixonrm@myspace.com  Female
# 995  996    Merrili       Alman       malmanrn@cornell.edu  Female
# 996  997    Winonah      Heckle          whecklero@fc2.com  Female
#
#      street_number street_name street_suffix          city         state  \
# 0              1.0   Trailsway          Road     San Diego    California
# ...

# %%
unique = Customers.drop_duplicates(subset = 'first_name')
unique
# Out:
#       id first_name   last_name                      email  gender  \
# 0      1     Romain   Southcott  rsouthcott0@clickbank.net    Male
# 1      2     Cosimo   Molyneaux      cmolyneaux1@wiley.com    Male
# 2      3      Bambi     Westrip     bwestrip2@symantec.com  Female
# 3      4     Roarke  Pankettman     rpankettman3@wiley.com    Male
# 4      5    Mikaela    Althorpe           malthorpe4@51.la     NaN
# ..   ...        ...         ...                        ...     ...
# 992  993    Johnath      Clancy      jclancyrk@smugmug.com  Female
# 993  994     Binnie      Dearth           bdearthrl@ed.gov     NaN
# 994  995      Brana       Dixon       bdixonrm@myspace.com  Female
# 995  996    Merrili       Alman       malmanrn@cornell.edu  Female
# 996  997    Winonah      Heckle          whecklero@fc2.com  Female
#
#      street_number street_name street_suffix          city         state  \
# 0              1.0   Trailsway          Road     San Diego    California
# ...

# %%
unique.dropna()
# Out:
#       id first_name   last_name                      email  gender  \
# 0      1     Romain   Southcott  rsouthcott0@clickbank.net    Male
# 2      3      Bambi     Westrip     bwestrip2@symantec.com  Female
# 3      4     Roarke  Pankettman     rpankettman3@wiley.com    Male
# 5      6  Magdalena      Cullip           mcullip5@tiny.cc  Female
# 6      7   Marietta      Heball          mheball6@blog.com  Female
# ..   ...        ...         ...                        ...     ...
# 988  989   Vivianne      Abbyss  vabbyssrg@squarespace.com  Female
# 992  993    Johnath      Clancy      jclancyrk@smugmug.com  Female
# 994  995      Brana       Dixon       bdixonrm@myspace.com  Female
# 995  996    Merrili       Alman       malmanrn@cornell.edu  Female
# 996  997    Winonah      Heckle          whecklero@fc2.com  Female
#
#      street_number street_name street_suffix          city         state  \
# 0              1.0   Trailsway          Road     San Diego    California
# ...

# %%
unique.dropna(axis = 1)
# Out:
#       id first_name   last_name  postcode country
# 0      1     Romain   Southcott     92127     USA
# 1      2     Cosimo   Molyneaux         0     USA
# 2      3      Bambi     Westrip     78220     USA
# 3      4     Roarke  Pankettman     38150     USA
# 4      5    Mikaela    Althorpe     83732     USA
# ..   ...        ...         ...       ...     ...
# 992  993    Johnath      Clancy     99812     USA
# 993  994     Binnie      Dearth     55441     USA
# 994  995      Brana       Dixon     55572     USA
# 995  996    Merrili       Alman     19610     USA
# 996  997    Winonah      Heckle     46278     USA
#
# [930 rows x 5 columns]

# %%
Customers['email'] = Customers['email'].fillna('unknown')
Customers
# Out:
#       id first_name   last_name                      email  gender  \
# 0      1     Romain   Southcott  rsouthcott0@clickbank.net    Male
# 1      2     Cosimo   Molyneaux      cmolyneaux1@wiley.com    Male
# 2      3      Bambi     Westrip     bwestrip2@symantec.com  Female
# 3      4     Roarke  Pankettman     rpankettman3@wiley.com    Male
# 4      5    Mikaela    Althorpe           malthorpe4@51.la     NaN
# ..   ...        ...         ...                        ...     ...
# 992  993    Johnath      Clancy      jclancyrk@smugmug.com  Female
# 993  994     Binnie      Dearth           bdearthrl@ed.gov     NaN
# 994  995      Brana       Dixon       bdixonrm@myspace.com  Female
# 995  996    Merrili       Alman       malmanrn@cornell.edu  Female
# 996  997    Winonah      Heckle          whecklero@fc2.com  Female
#
#      street_number street_name street_suffix          city         state  \
# 0              1.0   Trailsway          Road     San Diego    California
# ...

# %%
Customers['street_number'] = Customers['street_number'].ffill()
Customers
# Out:
#       id first_name   last_name                      email  gender  \
# 0      1     Romain   Southcott  rsouthcott0@clickbank.net    Male
# 1      2     Cosimo   Molyneaux      cmolyneaux1@wiley.com    Male
# 2      3      Bambi     Westrip     bwestrip2@symantec.com  Female
# 3      4     Roarke  Pankettman     rpankettman3@wiley.com    Male
# 4      5    Mikaela    Althorpe           malthorpe4@51.la     NaN
# ..   ...        ...         ...                        ...     ...
# 992  993    Johnath      Clancy      jclancyrk@smugmug.com  Female
# 993  994     Binnie      Dearth           bdearthrl@ed.gov     NaN
# 994  995      Brana       Dixon       bdixonrm@myspace.com  Female
# 995  996    Merrili       Alman       malmanrn@cornell.edu  Female
# 996  997    Winonah      Heckle          whecklero@fc2.com  Female
#
#      street_number street_name street_suffix          city         state  \
# 0              1.0   Trailsway          Road     San Diego    California
# ...

# %%
Customers['city'] = Customers['city'].bfill()
Customers
# Out:
#       id first_name   last_name                      email  gender  \
# 0      1     Romain   Southcott  rsouthcott0@clickbank.net    Male
# 1      2     Cosimo   Molyneaux      cmolyneaux1@wiley.com    Male
# 2      3      Bambi     Westrip     bwestrip2@symantec.com  Female
# 3      4     Roarke  Pankettman     rpankettman3@wiley.com    Male
# 4      5    Mikaela    Althorpe           malthorpe4@51.la     NaN
# ..   ...        ...         ...                        ...     ...
# 992  993    Johnath      Clancy      jclancyrk@smugmug.com  Female
# 993  994     Binnie      Dearth           bdearthrl@ed.gov     NaN
# 994  995      Brana       Dixon       bdixonrm@myspace.com  Female
# 995  996    Merrili       Alman       malmanrn@cornell.edu  Female
# 996  997    Winonah      Heckle          whecklero@fc2.com  Female
#
#      street_number street_name street_suffix          city         state  \
# 0              1.0   Trailsway          Road     San Diego    California
# ...

# %%
Customers['gender'] = Customers['gender'].fillna(Customers['gender'].mode()[0])
Customers
# Out:
#       id first_name   last_name                      email  gender  \
# 0      1     Romain   Southcott  rsouthcott0@clickbank.net    Male
# 1      2     Cosimo   Molyneaux      cmolyneaux1@wiley.com    Male
# 2      3      Bambi     Westrip     bwestrip2@symantec.com  Female
# 3      4     Roarke  Pankettman     rpankettman3@wiley.com    Male
# 4      5    Mikaela    Althorpe           malthorpe4@51.la    Male
# ..   ...        ...         ...                        ...     ...
# 992  993    Johnath      Clancy      jclancyrk@smugmug.com  Female
# 993  994     Binnie      Dearth           bdearthrl@ed.gov    Male
# 994  995      Brana       Dixon       bdixonrm@myspace.com  Female
# 995  996    Merrili       Alman       malmanrn@cornell.edu  Female
# 996  997    Winonah      Heckle          whecklero@fc2.com  Female
#
#      street_number street_name street_suffix          city         state  \
# 0              1.0   Trailsway          Road     San Diego    California
# ...

# %%
Products['cost'].min()
# Out:
# '$13.83'

# %%
Products.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 60 entries, 0 to 59
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  60 non-null     int64
#  1   id          60 non-null     int64
#  2   product     60 non-null     object
#  3   cost        60 non-null     float64
#  4   company     55 non-null     object
# dtypes: float64(1), int64(2), object(2)
# memory usage: 2.5+ KB

# %%
Products['cost'] = Products['cost'].astype('str').str.replace('[$,]','',regex = True).astype(float)

# %%
Products['cost'].mode()
# Out:
# 0    13.83
# Name: cost, dtype: float64

# %%
Customers['state'].mode()
# Out:
# 0    Texas
# Name: state, dtype: object

# %%
Products.select_dtypes(include = 'number').mean()
# Out:
# Unnamed: 0    29.500000
# id            30.500000
# cost          55.156167
# dtype: float64

# %%
Products.select_dtypes(include = 'number').sum()
# Out:
# Unnamed: 0    1770.00
# id            1830.00
# cost          3309.37
# dtype: float64

# %%
Customers.reset_index()
Customers
# Out:
#       id first_name   last_name                      email  gender  \
# 0      1     Romain   Southcott  rsouthcott0@clickbank.net    Male
# 1      2     Cosimo   Molyneaux      cmolyneaux1@wiley.com    Male
# 2      3      Bambi     Westrip     bwestrip2@symantec.com  Female
# 3      4     Roarke  Pankettman     rpankettman3@wiley.com    Male
# 4      5    Mikaela    Althorpe           malthorpe4@51.la    Male
# ..   ...        ...         ...                        ...     ...
# 992  993    Johnath      Clancy      jclancyrk@smugmug.com  Female
# 993  994     Binnie      Dearth           bdearthrl@ed.gov    Male
# 994  995      Brana       Dixon       bdixonrm@myspace.com  Female
# 995  996    Merrili       Alman       malmanrn@cornell.edu  Female
# 996  997    Winonah      Heckle          whecklero@fc2.com  Female
#
#      street_number street_name street_suffix          city         state  \
# 0              1.0   Trailsway          Road     San Diego    California
# ...

# %%
Products['company'].value_counts().head().reset_index()
# Out:
#       company  count
# 0    Livepath      2
# 1        Ntag      2
# 2  Browsezoom      2
# 3        Vitz      2
# 4     Cogibox      2

# %%
Products['company'].value_counts().head(10).plot(kind = 'bar')
# Out:
# <Axes: xlabel='company'>

# %%
Customers['gender'].value_counts().plot(kind = 'pie')
# Out:
# <Axes: ylabel='count'>

# %%
Products['cost'].aggregate('sum')
# Out:
# np.float64(3309.37)

# %%
Products['cost'].sum()
# Out:
# np.float64(3309.37)

# %%
Products['cost'].aggregate(['sum', 'mean', 'median']).reset_index()
# Out:
#     index         cost
# 0     sum  3309.370000
# 1    mean    55.156167
# 2  median    57.780000

# %%
Customers.sort_values(by = ['city', 'state'], ascending = [False,False] )
# Out:
#       id first_name  last_name                         email  gender  \
# 755  756   Margalit      Siley             msileykz@blog.com  Female
# 925  926   Harmonia        Erb                       unknown  Female
# 157  158    Calhoun    McNulty   cmcnulty4d@odnoklassniki.ru    Male
# 382  383      Locke      Segar            lsegaram@youku.com    Male
# 221  222       Alli  Dranfield  adranfield65@cyberchimps.com  Female
# ..   ...        ...        ...                           ...     ...
# 59    60      Billy    Micklem         bmicklem1n@nsw.gov.au    Male
# 214  215     Calvin     Dhenin         cdhenin5y@harvard.edu    Male
# 354  355   Julianna     Gammel             jgammel9u@who.int  Female
# 672  673       Esme   Tregenna      etregennaio@berkeley.edu    Male
# 956  957     Ruddie    Eckhard            reckhardqk@free.fr    Male
#
#      street_number       street_name street_suffix           city      state  \
# ...

# %%
Purchases['year'] = Purchases['purch_date'].dt.year
Purchases
# Out:
#       Unnamed: 0    id purch_date  customer_num  product_num  amount    paid  \
# 0              0     1 2019-01-03           823           27      12  568.92
# 1              1     2 2019-01-03           606           28      14  395.36
# 2              2     3 2019-01-03           955            9      17  510.17
# 3              3     4 2019-01-03           577           19       3   68.49
# 4              4     5 2019-01-03           429            8      18  759.42
# ...          ...   ...        ...           ...          ...     ...     ...
# 5995        5995  5996 2019-06-20           893           33       5  411.10
# 5996        5996  5997 2019-06-20           566           23      11  178.97
# 5997        5997  5998 2019-06-20           114           19       9  205.47
# 5998        5998  5999 2019-06-20           404           11      20  429.40
# 5999        5999  6000 2019-06-20            88           57       4  274.52
#
#       year
# 0     2019
# 1     2019
# ...

# %%
Purchases['month'] = Purchases['purch_date'].dt.month
Purchases
# Out:
#       Unnamed: 0    id purch_date  customer_num  product_num  amount    paid  \
# 0              0     1 2019-01-03           823           27      12  568.92
# 1              1     2 2019-01-03           606           28      14  395.36
# 2              2     3 2019-01-03           955            9      17  510.17
# 3              3     4 2019-01-03           577           19       3   68.49
# 4              4     5 2019-01-03           429            8      18  759.42
# ...          ...   ...        ...           ...          ...     ...     ...
# 5995        5995  5996 2019-06-20           893           33       5  411.10
# 5996        5996  5997 2019-06-20           566           23      11  178.97
# 5997        5997  5998 2019-06-20           114           19       9  205.47
# 5998        5998  5999 2019-06-20           404           11      20  429.40
# 5999        5999  6000 2019-06-20            88           57       4  274.52
#
#       year  month
# 0     2019      1
# ...

# %%
Purchases[Purchases['purch_date'].between('2019','2020')]
# Out:
#       Unnamed: 0    id purch_date  customer_num  product_num  amount    paid  \
# 0              0     1 2019-01-03           823           27      12  568.92
# 1              1     2 2019-01-03           606           28      14  395.36
# 2              2     3 2019-01-03           955            9      17  510.17
# 3              3     4 2019-01-03           577           19       3   68.49
# 4              4     5 2019-01-03           429            8      18  759.42
# ...          ...   ...        ...           ...          ...     ...     ...
# 5995        5995  5996 2019-06-20           893           33       5  411.10
# 5996        5996  5997 2019-06-20           566           23      11  178.97
# 5997        5997  5998 2019-06-20           114           19       9  205.47
# 5998        5998  5999 2019-06-20           404           11      20  429.40
# 5999        5999  6000 2019-06-20            88           57       4  274.52
#
#       year  month
# 0     2019      1
# ...

# %%
company_list = ['Ntag', 'oloo']
Products[Products['company'].isin(company_list)]
# Out:
#     Unnamed: 0  id                         product   cost company
# 2            2   3              Bar Bran Honey Nut  65.40    Ntag
# 30          30  31  Wine - Carmenere Casillero Del  55.77    Ntag

# %%
Products
# Out:
#     Unnamed: 0  id                             product   cost       company
# 0            0   1                Liners - Baking Cups   6.36      Skipfire
# 1            1   2          Nori Sea Weed - Gold Label  85.74       Dynazzy
# 2            2   3                  Bar Bran Honey Nut  65.40          Ntag
# 3            3   4          Soup - Campbells Beef Stew  68.16      Photojam
# 4            4   5    Wine - Shiraz Wolf Blass Premium  87.39          Eare
# 5            5   6  Wine - White, Riesling, Semi - Dry  99.22      Livepath
# 6            6   7                        Brandy - Bar  13.83          Oloo
# 7            7   8                      Onions - White  42.19          Oozz
# 8            8   9         Lettuce - Baby Salad Greens  30.01        Meevee
# 9            9  10                Sambuca - Ramazzotti  88.99      Livepath
# 10          10  11                Coffee - Decafenated  21.47        Meezzy
# ...

# %%
Products.groupby('company')['cost'].sum().reset_index().sort_values(by = 'cost' , ascending = False)
# Out:
#          company    cost
# 19      Livepath  188.21
# 25          Ntag  121.17
# 4        Cogibox  102.27
# 39        Skyble   99.54
# 6        Dynabox   99.40
# 11        Eimbee   98.74
# 18      Linkbuzz   95.68
# 23          Muxo   92.33
# 34      Realcube   90.48
# 46      Wordware   87.51
# 8           Eare   87.39
# 42        Trunyx   87.05
# 7        Dynazzy   85.74
# 37       Skinder   84.20
# 45       Voonder   82.22
# 3     Browsezoom   82.10
# 14      Fliptune   75.32
# 9          Eazzy   74.28
# 41   Topiclounge   74.06
# 16       Innojam   73.70
# 47        Yakijo   73.05
# 12      Fanoodle   68.63
# 30      Photojam   68.16
# 20         Meemm   65.35
# 1     Babbleopia   63.98
# 15         Gevee   62.60
# 35     Realpoint   61.99
# 31     Photolist   59.23
# 0          Aibox   56.33
# 40  Thoughtstorm   45.77
# 44          Vitz   45.39
# 29     Photofeed   42.56
# 28          Oozz   42.19
# 33         Quinu   41.22
# 10      Edgeclub   40.69
# 13     Flipstorm   37.79
# ...

# %%
Purchases.groupby('month')[['paid','amount']].sum()
# Out:
#             paid  amount
# month
# 1      139986.42    2643
# 2       83532.80    1713
# 3      890751.05   16752
# 4      715885.30   14268
# 5      550416.29   10537
# 6      271329.22    5457
# 7      112608.31    2063
# 8      118668.27    2291
# 9       94420.38    1962
# 10      92266.35    1695
# 11     111315.89    2044
# 12     112047.84    2032

# %%
Purchases.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6000 entries, 0 to 5999
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Unnamed: 0    6000 non-null   int64
#  1   id            6000 non-null   int64
#  2   purch_date    6000 non-null   datetime64[ns]
#  3   customer_num  6000 non-null   int64
#  4   product_num   6000 non-null   int64
#  5   amount        6000 non-null   int64
#  6   paid          6000 non-null   float64
#  7   year          6000 non-null   int32
#  8   month         6000 non-null   int32
# dtypes: datetime64[ns](1), float64(1), int32(2), int64(5)
# memory usage: 375.1 KB

# %%
Customers['gender'].idxmax()
# Out:
# 0

# %%
Products
# Out:
#     Unnamed: 0  id                             product   cost       company
# 0            0   1                Liners - Baking Cups   6.36      Skipfire
# 1            1   2          Nori Sea Weed - Gold Label  85.74       Dynazzy
# 2            2   3                  Bar Bran Honey Nut  65.40          Ntag
# 3            3   4          Soup - Campbells Beef Stew  68.16      Photojam
# 4            4   5    Wine - Shiraz Wolf Blass Premium  87.39          Eare
# 5            5   6  Wine - White, Riesling, Semi - Dry  99.22      Livepath
# 6            6   7                        Brandy - Bar  13.83          Oloo
# 7            7   8                      Onions - White  42.19          Oozz
# 8            8   9         Lettuce - Baby Salad Greens  30.01        Meevee
# 9            9  10                Sambuca - Ramazzotti  88.99      Livepath
# 10          10  11                Coffee - Decafenated  21.47        Meezzy
# ...

# %%
pivot_table = pd.pivot_table(
                      data = Products,
                      values = ['cost', 'id'],
                      index = 'company',
                      aggfunc = 'sum',
                      fill_value = 0
                      )
pivot_table
# Out:
#                 cost  id
# company
# Aibox          56.33  18
# Babbleopia     63.98  50
# Brainsphere    22.83  19
# Browsezoom     82.10  64
# Cogibox       102.27  70
# Digitube        8.55  55
# Dynabox        99.40  14
# Dynazzy        85.74   2
# Eare           87.39   5
# Eazzy          74.28  59
# Edgeclub       40.69  43
# Eimbee         98.74  52
# Fanoodle       68.63  57
# Flipstorm      37.79  54
# Fliptune       75.32  51
# Gevee          62.60  49
# Innojam        73.70  25
# Jabbersphere   30.67  44
# Linkbuzz       95.68  35
# Livepath      188.21  16
# Meemm          65.35  41
# Meevee         30.01   9
# Meezzy         21.47  11
# Muxo           92.33  32
# Mynte          21.98  38
# Ntag          121.17  34
# Oloo           13.83   7
# Oodoo          37.45  39
# Oozz           42.19   8
# Photofeed      42.56  12
# Photojam       68.16   4
# Photolist      59.23  29
# Quatz          13.83  36
# Quinu          41.22  60
# Realcube       90.48  21
# ...

# %%
data = {
    'name': ['A', 'A', 'B', 'B'],
    'subject': ['Math', 'Science', 'Math', 'Science'],
    'marks': [80, 90, 70, 85]
}

df = pd.DataFrame(data)
df
# Out:
#   name  subject  marks
# 0    A     Math     80
# 1    A  Science     90
# 2    B     Math     70
# 3    B  Science     85

# %%
pivot_table = pd.pivot_table(
    data = df,
    values = 'marks',
    aggfunc = 'sum',
    columns = 'subject',
    index = 'name'
)
pivot_table
# Out:
# subject  Math  Science
# name
# A          80       90
# B          70       85

# %%
cross = pd.crosstab(df['name'], df['subject'])
cross
# Out:
# subject  Math  Science
# name
# A           1        1
# B           1        1

# %%
df = pd.DataFrame({
    'name': ['A', 'B'],
    'Math': [80, 70],
    'Science': [90, 85]
})
df
# Out:
#   name  Math  Science
# 0    A    80       90
# 1    B    70       85

# %%
melt_df = pd.melt(
               df,
               id_vars = 'name',
               value_vars = ['Math' ,'Science'],
               var_name = 'subject',
               value_name = 'marks'
               
)
melt_df
# Out:
#   name  subject  marks
# 0    A     Math     80
# 1    B     Math     70
# 2    A  Science     90
# 3    B  Science     85

# %%
df = pd.DataFrame({
    'id': [1, 2],
    'Jan': [100, 200],
    'Feb': [150, 250],
    'Mar': [180, 300]
})
df
# Out:
#    id  Jan  Feb  Mar
# 0   1  100  150  180
# 1   2  200  250  300

# %%
melt_df = pd.melt(
    df,
    id_vars = 'id',
    value_vars = ['Jan', 'Feb'],
    var_name = 'month',
    value_name = 'sales'
)
melt_df
# Out:
#    id month  sales
# 0   1   Jan    100
# 1   2   Jan    200
# 2   1   Feb    150
# 3   2   Feb    250
