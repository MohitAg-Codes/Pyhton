# %%
x = 10
y = 6
print(x & y)
print(x | y)
print(x ^ y)
print(x >> y)
print(x << y)
print(~y)
# Out:
# 2
# 14
# 12
# 0
# 640
# -7

# %%
print(10^6)
# Out:
# 12

# %%
*a,b,c = 10,20,30,40,50,60
print(a)
print(b)
print(c)
# Out:
# [10, 20, 30, 40]
# 50
# 60

# %%
print(~117980090)
# Out:
# -117980091

# %%
x = -10
print(~x)
# Out:
# 9

# %%
print(10>>2)
# Out:
# 2

# %%
print(10>>3)
# Out:
# 1

# %%
print(17>>3)
# Out:
# 2

# %%
x = 10
y = 11
z = 7
x+=y
print(x)
x-=z
print(x)
x/=2
print(x)
# Out:
# 21
# 14
# 7.0

# %%
print('i' in 'india')
# Out:
# True

# %%
print('i' not in 'india')
# Out:
# False

# %%
a = [1,2,3]
b=a
c = [1,2,3]
print(a is b)
# Out:
# True

# %%
print(a is c)
# Out:
# False

# %%
x=10
y=10
print(x is y)
print(id(x))
print(id(y))
# Out:
# True
# 140725327672520
# 140725327672520

# %%
cond1
